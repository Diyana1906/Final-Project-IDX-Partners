# %% [markdown]
# # Import Library

# %%
import numpy as np 

import pandas as pd 
#code untuk membuat kolom tabel dapat ditampilkan semua 
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',99)

import matplotlib.pyplot as plt 
import seaborn as sns 
sns.set()

# %%
df = pd.read_csv('loan_data_2007_2014.csv', index_col=0)
df.head()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_5484\1883642690.py:1: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('loan_data_2007_2014.csv', index_col=0)
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#    int_rate  installment grade sub_grade                 emp_title emp_length  \
# 0     10.65       162.87     B        B2                       NaN  10+ years
# 1     15.27        59.83     C        C4                     Ryder   < 1 year
# ...

# %% [markdown]
# # Exploring Data

# %%
df.shape
# Out:
# (466285, 74)

# %%
df.sample()
# Out:
#               id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 418088  13266522   15308772      13275        13275          13275.0
#
#               term  int_rate  installment grade sub_grade         emp_title  \
# 418088   36 months      7.62       413.67     A        A3  School principal
#
#        emp_length home_ownership  annual_inc verification_status issue_d  \
# 418088  10+ years            OWN    103000.0        Not Verified  Mar-14
#
#        loan_status pymnt_plan  \
# 418088     Current          n
#
#                                                       url desc  \
# 418088  https://www.lendingclub.com/browse/loanDetail....  NaN
#
#                purpose           title zip_code addr_state   dti  delinq_2yrs  \
# 418088  major_purchase  Major purchase    480xx         MI  1.47          0.0
#
#        earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 418088           Jun-94             0.0                     NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 466285 entries, 0 to 466284
# Data columns (total 74 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   id                           466285 non-null  int64
#  1   member_id                    466285 non-null  int64
#  2   loan_amnt                    466285 non-null  int64
#  3   funded_amnt                  466285 non-null  int64
#  4   funded_amnt_inv              466285 non-null  float64
#  5   term                         466285 non-null  object
#  6   int_rate                     466285 non-null  float64
#  7   installment                  466285 non-null  float64
#  8   grade                        466285 non-null  object
#  9   sub_grade                    466285 non-null  object
#  10  emp_title                    438697 non-null  object
#  11  emp_length                   445277 non-null  object
# ...

# %% [markdown]
# Pengamatan
# 1. Data terdiri dari 466285 baris
# 2. Tampak beberapa kolom masih memiliki null/missing values (Non-Null Count < jumlah baris)
# 3. Tipe kolom emp_length, issue_d , earliest_cr_line, last_pymnt_d, next_pymnt_d, last_credit_pull_d memiliki tipe yang salah (seharusnya dalam bentuk int), sedangkan kolom lainnya sepertinya tidak ada issue yang mencolok pada tipe data (sudah sesuai)
# 4. Ada beberapa fitur kolom tidak berguna karena memiliki nilai kosong semua (Null)

# %%
df.id.nunique()
# Out:
# 466285

# %%
df.member_id.nunique()
# Out:
# 466285

# %% [markdown]
# Terlihat bahwa tidak ada `id` atau `member_id` yang duplikat, artinya setiap baris sudah mewakili satu individu.

# %% [markdown]
# Selanjutnya, pembuangan fitur-fitur yang tidak berguna dilakukan. Contohnya seperti fitur yang merupakan id unik, berupa free text, nilainya kosong semua (NULL), dsb.

# %% [markdown]
# # Data Cleaning

# %%
df.isna().sum()
# Out:
# id                                  0
# member_id                           0
# loan_amnt                           0
# funded_amnt                         0
# funded_amnt_inv                     0
# term                                0
# int_rate                            0
# installment                         0
# grade                               0
# sub_grade                           0
# emp_title                       27588
# emp_length                      21008
# home_ownership                      0
# annual_inc                          4
# verification_status                 0
# issue_d                             0
# loan_status                         0
# pymnt_plan                          0
# url                                 0
# desc                           340302
# purpose                             0
# title                              20
# zip_code                            0
# addr_state                          0
# dti                                 0
# ...

# %% [markdown]
# #### Jika ada kolom dengan data kosong yang sangat banyak, maka kolom tersebut bisa dihapus aja

# %%
# kolom all null 
cols_to_drop= ['inq_last_12m','total_cu_tl','inq_fi','open_acc_6m','open_il_6m','open_il_12m','open_il_24m','mths_since_rcnt_il','total_bal_il','il_util','open_rv_12m','open_rv_24m','max_bal_bc','all_util','annual_inc_joint','dti_joint', 'verification_status_joint'
              # drop kolom free text (data  tidak berguna)
, 'url','desc']

# %%
df_1 = df.drop(cols_to_drop, axis=1)

# %%
df_1.sample(5)
# Out:
#               id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 34321     454473     562832       7000         7000           7000.0
# 401959  14789207   16861633       3375         3375           3375.0
# 183966   1904826    2216993      10000        10000          10000.0
# 45230   10065862   11917935       2400         2400           2400.0
# 277949  31217306   33790535       5000         5000           5000.0
#
#               term  int_rate  installment grade sub_grade  \
# 34321    36 months      7.40       217.42     A        A2
# 401959   36 months     16.59       119.65     D        D1
# 183966   36 months     13.11       337.47     B        B4
# 45230    36 months     13.98        82.01     C        C1
# 277949   36 months      6.49       153.23     A        A2
#
#                      emp_title emp_length home_ownership  annual_inc  \
# 34321             City of Mesa   < 1 year       MORTGAGE     40224.0
# ...

# %%
df_1.isna().sum()
# Out:
# id                                  0
# member_id                           0
# loan_amnt                           0
# funded_amnt                         0
# funded_amnt_inv                     0
# term                                0
# int_rate                            0
# installment                         0
# grade                               0
# sub_grade                           0
# emp_title                       27588
# emp_length                      21008
# home_ownership                      0
# annual_inc                          4
# verification_status                 0
# issue_d                             0
# loan_status                         0
# pymnt_plan                          0
# purpose                             0
# title                              20
# zip_code                            0
# addr_state                          0
# dti                                 0
# delinq_2yrs                        29
# earliest_cr_line                   29
# ...
